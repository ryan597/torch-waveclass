# %%
import argparse
import time
from comet_ml import Experiment
import torch
import h5py
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import models
from torchvision import transforms as T
from sklearn.metrics import classification_report

# %%
valid = utils.h5_dataloader('data/H5_files/valid.h5', transform=T.ToTensor(), batch_size=20, shuffle=False, num_workers=2)

# %%
a = valid.dataset
rand_indx = np.random.random_integers(0, 100, 10)
for i, _ in enumerate(a):
    b = a.images[rand_indx[i]]
    print(b)
    print(np.shape(b))
    break
# Out:
# [[104  97  90 ... 234 235 245]
#  [104 103  94 ... 238 222 245]
#  [ 90  97 115 ... 223 232 229]
#  ...
#  [156 162 160 ... 158 160 160]
#  [142 158 153 ... 169 157 170]
#  [152 172 166 ... 151 152 155]]
# (480, 640)

# %%
myutils.view_batch(valid)
# Out:
# 92
# 0
# plunge
# 711
# 2
# nonbreaking
# 1277
# 2
# nonbreaking
# 124
# 0
# plunge
# 300
# 0
# plunge
# 1340
# 2
# nonbreaking
# 879
# 2
# nonbreaking
# 1345
# 2
# nonbreaking
# 1193
# 2
# nonbreaking

# %%
for i, b in enumerate(valid):
    im, lb = b
    print(torch.max(im))
    break
# Out:
# tensor(1.)

# %%
vgg = models.vgg16

# %%
mycnn = vgg(pretrained=True)

# %%
vgg
# Out:
# <function torchvision.models.vgg.vgg16(pretrained=False, progress=True, **kwargs)>

# %%
mycnn
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
# ...

# %%
vgg = model_dict['vgg16']

# %%
vgg
# Out:
# <function torchvision.models.vgg.vgg16(pretrained=False, progress=True, **kwargs)>

# %%
vgg = vgg(pretrained=True)

# %%
vgg
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
# ...

# %%
mobarr = [[0.485, 0.456, 0.406], [0.229, 0.224, 0.225]]

pretrain_transform = T.Compose([
    # mobilenet_v2 normalize
    T.Normalize(mobarr[0], mobarr[1])
    ])

# %%
pretrain_transform
# Out:
# Compose(
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )

# %%
from models import my_CNNs
import my_utils 
from callbacks import callbacks
from data import transformations
# Out:
# Traceback (most recent call last):
#
#   File "/home/ryan/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-2-8967cb022938>", line 4, in <module>
#     from data import transformations
#
#   File "/home/ryan/Documents/PHD/CODES/waveclass/data/transformations.py", line 5
#     "resnet18" :   [[,,], [,,]],
#                      ^
# SyntaxError: invalid syntax

# %%
a = my_CNNs.Net()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-69bd18d49d62> in <module>
# ----> 1 a = my_CNNs.Net()
#
# TypeError: __init__() missing 1 required positional argument: 'base'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9fde25ea7b97> in <module>
# ----> 1 a = Net()
#
# NameError: name 'Net' is not defined
